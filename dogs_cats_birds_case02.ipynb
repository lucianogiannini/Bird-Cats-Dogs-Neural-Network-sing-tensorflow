# %%
# using tf.2.1 in colab
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2

from google.colab import drive
drive.mount('/content/gdrive')
# sanity check for the tf version
print(tf.__version__)

###################################################################################################
# Define image size for network model -- all input images are scaled to this size.
###################################################################################################   
img_width, img_height = 150, 150

###################################################################################################
# Include pointers to training and validation data folders -- be sure to examine subfolder structure
# --> I also define the # of training samples, validation samples, epochs, and batch size here.
###################################################################################################   
train_data_dir = '/content/gdrive/My Drive/cse-30321-lab2/Datasets/data/train'
validation_data_dir = '/content/gdrive/My Drive/cse-30321-lab2/Datasets/data/validation'
nb_train_samples = 5000
nb_validation_samples = 1000
epochs = 30
batch_size = 100

###################################################################################################
# As before, this code simply organizes input data such that channels either come first or last
# depending on the backend used (TensorFlow or Theano)
###################################################################################################   
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

###################################################################################################
# Define our CNN model
###################################################################################################
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

################################################
#Layer 2
model.add(Conv2D(64, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#Layer 3
model.add(Conv2D(64, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#Layer 4
model.add(Conv2D(64, (5, 5), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#Layer 5
model.add(Conv2D(64, (5, 5), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


################################################

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dense(3))
model.add(Activation('softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

###################################################################################################
# To process images in respective directories, we can use the ImageDataGenerator class
#	The code provided here normalizes image data, etc.
#	The parameters will not be discussed further here, 
#    but more information / options can be found at:  https://keras.io/preprocessing/image/ 
###################################################################################################   
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

###################################################################################################
# This is the augmentation configuration we will use for testing:  only rescaling
###################################################################################################
test_datagen = ImageDataGenerator(rescale=1. / 255)

###################################################################################################
# Subsequent invocations of flow_from_directory() will use the paths to the training and validation 
# data, and generate batches of data
# 
# Note that if you wanted to work with grayscale images (for example) you could simply change 
# color_mode to ‘gray_scale’ (and the number of color channels)
# 
# Again, you will not need to change any parameters here, but a more detailed description of this 
# class can also be found at the link above.
###################################################################################################
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

###################################################################################################
# Finally, the invocation of model.fit_generator will simply train the model on batches of data.  
# More information can be found at:  https://keras.io/models/sequential/
# --> However, this is just analogous to model.fit() discussed in other examples.
###################################################################################################

history = model.fit(
    train_generator,
    steps_per_epoch= nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

import pandas as pd
hist_df = pd.DataFrame(history.history) 
hist_csv_file = '/content/gdrive/My Drive/cse-30321-lab2/dogs_cats_birds_model_case02_30epoch.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

###################################################################################################
# Here, we save the model weights and generate an image of the network...
###################################################################################################
model.save('/content/gdrive/My Drive/cse-30321-lab2/dogs_cats_birds_model_case02_30epoch')

plot_model(model, to_file='/content/gdrive/My Drive/cse-30321-lab2/dogs_cats_birds_model_case02.png', show_shapes=True, show_layer_names=True)
# Out:
# Mounted at /content/gdrive
# 2.8.0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  activation_1 (Activation)   (None, 72, 72, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        36928
#
#  activation_2 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        102464
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 64)          102464
#
#  activation_4 (Activation)   (None, 2, 2, 64)          0
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  activation_5 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
#  activation_6 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 265,603
# Trainable params: 265,603
# Non-trainable params: 0
# _________________________________________________________________
# Found 22290 images belonging to 3 classes.
# Found 5696 images belonging to 3 classes.
# Epoch 1/30
# 11/50 [=====>........................] - ETA: 13:27 - loss: 1.0082 - accuracy: 0.4518
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 50/50 [==============================] - 1399s 27s/step - loss: 0.9541 - accuracy: 0.4548 - val_loss: 0.9337 - val_accuracy: 0.5270
# Epoch 2/30
# 50/50 [==============================] - 1045s 21s/step - loss: 0.8296 - accuracy: 0.5306 - val_loss: 0.8510 - val_accuracy: 0.5560
# Epoch 3/30
# 50/50 [==============================] - 832s 17s/step - loss: 0.7909 - accuracy: 0.5830 - val_loss: 0.8848 - val_accuracy: 0.5560
# Epoch 4/30
# 50/50 [==============================] - 674s 13s/step - loss: 0.7604 - accuracy: 0.6096 - val_loss: 0.7777 - val_accuracy: 0.6270
# Epoch 5/30
# 50/50 [==============================] - 546s 11s/step - loss: 0.7305 - accuracy: 0.6270 - val_loss: 0.8021 - val_accuracy: 0.6090
# Epoch 6/30
# 50/50 [==============================] - 475s 9s/step - loss: 0.6964 - accuracy: 0.6496 - val_loss: 0.6354 - val_accuracy: 0.7220
# Epoch 7/30
# 50/50 [==============================] - 396s 8s/step - loss: 0.6644 - accuracy: 0.6778 - val_loss: 0.6789 - val_accuracy: 0.6890
# Epoch 8/30
# 50/50 [==============================] - 346s 7s/step - loss: 0.6406 - accuracy: 0.6978 - val_loss: 0.6221 - val_accuracy: 0.7190
# Epoch 9/30
# 50/50 [==============================] - 314s 6s/step - loss: 0.6232 - accuracy: 0.7094 - val_loss: 0.6636 - val_accuracy: 0.6770
# Epoch 10/30
# 50/50 [==============================] - 288s 6s/step - loss: 0.5869 - accuracy: 0.7372 - val_loss: 0.5887 - val_accuracy: 0.7370
# Epoch 11/30
# 50/50 [==============================] - 280s 6s/step - loss: 0.5752 - accuracy: 0.7294 - val_loss: 0.5366 - val_accuracy: 0.7700
# Epoch 12/30
# 50/50 [==============================] - 274s 5s/step - loss: 0.5590 - accuracy: 0.7502 - val_loss: 0.5667 - val_accuracy: 0.7490
# Epoch 13/30
# 50/50 [==============================] - 267s 5s/step - loss: 0.5306 - accuracy: 0.7609 - val_loss: 0.8067 - val_accuracy: 0.6890
# Epoch 14/30
# 50/50 [==============================] - 272s 5s/step - loss: 0.5222 - accuracy: 0.7722 - val_loss: 0.6113 - val_accuracy: 0.7510
# Epoch 15/30
# 50/50 [==============================] - 269s 5s/step - loss: 0.4965 - accuracy: 0.7832 - val_loss: 0.7208 - val_accuracy: 0.7040
# Epoch 16/30
# 50/50 [==============================] - 264s 5s/step - loss: 0.4709 - accuracy: 0.7942 - val_loss: 0.6249 - val_accuracy: 0.7510
# Epoch 17/30
# 50/50 [==============================] - 262s 5s/step - loss: 0.4840 - accuracy: 0.7994 - val_loss: 0.5277 - val_accuracy: 0.7850
# Epoch 18/30
# 50/50 [==============================] - 262s 5s/step - loss: 0.4486 - accuracy: 0.8108 - val_loss: 0.4769 - val_accuracy: 0.8000
# Epoch 19/30
# 50/50 [==============================] - 257s 5s/step - loss: 0.4431 - accuracy: 0.8086 - val_loss: 0.4775 - val_accuracy: 0.8140
# Epoch 20/30
# 50/50 [==============================] - 258s 5s/step - loss: 0.4080 - accuracy: 0.8290 - val_loss: 0.5010 - val_accuracy: 0.8040
# Epoch 21/30
# 50/50 [==============================] - 253s 5s/step - loss: 0.4321 - accuracy: 0.8140 - val_loss: 0.5761 - val_accuracy: 0.7590
# Epoch 22/30
# 50/50 [==============================] - 254s 5s/step - loss: 0.3844 - accuracy: 0.8382 - val_loss: 0.5351 - val_accuracy: 0.7720
# Epoch 23/30
# 50/50 [==============================] - 260s 5s/step - loss: 0.4044 - accuracy: 0.8312 - val_loss: 0.4084 - val_accuracy: 0.8330
# Epoch 24/30
# 50/50 [==============================] - 256s 5s/step - loss: 0.3925 - accuracy: 0.8363 - val_loss: 0.4054 - val_accuracy: 0.8310
# Epoch 25/30
# 50/50 [==============================] - 262s 5s/step - loss: 0.3944 - accuracy: 0.8352 - val_loss: 0.4685 - val_accuracy: 0.8130
# Epoch 26/30
# 50/50 [==============================] - 254s 5s/step - loss: 0.3673 - accuracy: 0.8422 - val_loss: 0.4682 - val_accuracy: 0.7880
# Epoch 27/30
# 50/50 [==============================] - 259s 5s/step - loss: 0.3502 - accuracy: 0.8517 - val_loss: 0.4139 - val_accuracy: 0.8240
# Epoch 28/30
# 50/50 [==============================] - 255s 5s/step - loss: 0.3574 - accuracy: 0.8527 - val_loss: 0.4410 - val_accuracy: 0.8190
# Epoch 29/30
# 50/50 [==============================] - 258s 5s/step - loss: 0.3506 - accuracy: 0.8562 - val_loss: 0.4691 - val_accuracy: 0.8040
# Epoch 30/30
# 50/50 [==============================] - 258s 5s/step - loss: 0.3491 - accuracy: 0.8541 - val_loss: 0.3509 - val_accuracy: 0.8580
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/cse-30321-lab2/dogs_cats_birds_model_case02_30epoch/assets
